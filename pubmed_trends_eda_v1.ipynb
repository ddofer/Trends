# %% [markdown]
# * https://esperr.github.io/pubmed-by-year/?q1=(sleep)%20AND%20(review[Publication%20Type])&q2=(sleep)%20NOT%20(review[Publication%20Type])&q3=antibiotic%20AND%20(review[Publication%20Type])&q4=antibiotic%20NOT%20(review[Publication%20Type])&q5=antibiotic%20NOT%20(review[Publication%20Type])&q6=antibiotic%20resistant&startyear=1945
#
#
# Another (formatting broken):
# * esperr.github.io/pubmed-by-year/?q1=(ncRNA) AND (review[Publication Type])&q2=(PINK1) AND (review[Publication Type])&q3=(ncRNA) NOT (review[Publication Type])&q4=(PINK1) NOT (review[Publication Type])&q5=(microRNA,miRNA) AND (review[Publication Type])&q6=(microRNA,miRNA) NOT (review[Publication Type])&startyear=1980&endyear=2020

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import seaborn

# %%
df = pd.read_csv("PubMed by Year - antibiotic.csv",parse_dates=["Year"]).set_index("Year")
display(df.describe().round(2))
df
# Out:
#        (sleep) AND (review[Publication Type])  \
# count                                   77.00
# mean                                    59.58
# std                                     57.92
# min                                      0.00
# 25%                                     12.76
# 50%                                     30.37
# 75%                                    123.35
# max                                    180.65
#
#        (sleep) NOT (review[Publication Type])  \
# count                                   77.00
# mean                                   469.84
# std                                    250.02
# min                                     84.55
# 25%                                    281.77
# 50%                                    453.22
# 75%                                    565.94
# max                                   1211.36
#
#        antibiotic AND (review[Publication Type])  \
# count                                      77.00
# mean                                      192.86
# std                                       142.78
# min                                         0.00
# 25%                                        76.03
# 50%                                       170.13
# 75%                                       315.16
# max                                       426.70
#
#        antibiotic NOT (review[Publication Type])  antibiotic resistant
# count                                      77.00                 77.00
# mean                                     3045.21                539.69
# std                                       642.21                248.75
# min                                      2123.63                 73.12
# 25%                                      2512.98                392.02
# 50%                                      2888.18                516.03
# 75%                                      3448.54                748.43
# max                                      5080.89               1089.28
#             (sleep) AND (review[Publication Type])  \
# Year
# 1945-01-01                                0.000000
# 1946-01-01                                0.000000
# 1947-01-01                                0.000000
# 1948-01-01                                0.000000
# 1949-01-01                                0.000000
# ...                                            ...
# 2017-01-01                              180.654886
# 2018-01-01                              160.598100
# 2019-01-01                              149.280125
# 2020-01-01                              148.096170
# 2021-01-01                              162.721529
#
#             (sleep) NOT (review[Publication Type])  \
# Year
# 1945-01-01                              136.498806
# 1946-01-01                              113.105392
# 1947-01-01                               84.550346
# 1948-01-01                              110.236443
# 1949-01-01                              116.193932
# ...                                            ...
# 2017-01-01                              966.971774
# 2018-01-01                             1007.286739
# 2019-01-01                             1067.189550
# 2020-01-01                             1130.295084
# 2021-01-01                             1211.358650
#
#             antibiotic AND (review[Publication Type])  \
# Year
# 1945-01-01                                   0.000000
# 1946-01-01                                   0.000000
# 1947-01-01                                   0.000000
# 1948-01-01                                   2.826575
# 1949-01-01                                   0.000000
# ...                                               ...
# 2017-01-01                                 330.535510
# 2018-01-01                                 305.738354
# 2019-01-01                                 303.318465
# 2020-01-01                                 299.885512
# 2021-01-01                                 273.589895
#
#             antibiotic NOT (review[Publication Type])  antibiotic resistant
# Year
# 1945-01-01                                3085.847999             73.124360
# 1946-01-01                                4103.315286            100.126085
# 1947-01-01                                3904.688701            118.370484
# 1948-01-01                                4002.430855            120.129457
# 1949-01-01                                4302.358896            152.802980
# ...                                               ...                   ...
# 2017-01-01                                2432.164244            978.099624
# 2018-01-01                                2512.122890           1028.987177
# 2019-01-01                                2618.296687           1089.276190
# 2020-01-01                                2462.914405           1062.463838
# 2021-01-01                                2123.630546            978.563730
#
# [77 rows x 5 columns]

# %%
df = df.replace(0,np.nan)  ## may not make sense - what about intermediate years with 0? 
df
# Out:
#             (sleep) AND (review[Publication Type])  \
# Year
# 1945-01-01                                     NaN
# 1946-01-01                                     NaN
# 1947-01-01                                     NaN
# 1948-01-01                                     NaN
# 1949-01-01                                     NaN
# ...                                            ...
# 2017-01-01                              180.654886
# 2018-01-01                              160.598100
# 2019-01-01                              149.280125
# 2020-01-01                              148.096170
# 2021-01-01                              162.721529
#
#             (sleep) NOT (review[Publication Type])  \
# Year
# 1945-01-01                              136.498806
# 1946-01-01                              113.105392
# 1947-01-01                               84.550346
# 1948-01-01                              110.236443
# 1949-01-01                              116.193932
# ...                                            ...
# 2017-01-01                              966.971774
# 2018-01-01                             1007.286739
# 2019-01-01                             1067.189550
# 2020-01-01                             1130.295084
# 2021-01-01                             1211.358650
#
#             antibiotic AND (review[Publication Type])  \
# Year
# 1945-01-01                                        NaN
# 1946-01-01                                        NaN
# 1947-01-01                                        NaN
# 1948-01-01                                   2.826575
# 1949-01-01                                        NaN
# ...                                               ...
# 2017-01-01                                 330.535510
# 2018-01-01                                 305.738354
# 2019-01-01                                 303.318465
# 2020-01-01                                 299.885512
# 2021-01-01                                 273.589895
#
#             antibiotic NOT (review[Publication Type])  antibiotic resistant
# Year
# 1945-01-01                                3085.847999             73.124360
# 1946-01-01                                4103.315286            100.126085
# 1947-01-01                                3904.688701            118.370484
# 1948-01-01                                4002.430855            120.129457
# 1949-01-01                                4302.358896            152.802980
# ...                                               ...                   ...
# 2017-01-01                                2432.164244            978.099624
# 2018-01-01                                2512.122890           1028.987177
# 2019-01-01                                2618.296687           1089.276190
# 2020-01-01                                2462.914405           1062.463838
# 2021-01-01                                2123.630546            978.563730
#
# [77 rows x 5 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# ### 1st order difference makesi t easier to see big changes
# * Note major OOM between topics

# %%
df.diff().plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df.apply(np.log1p).diff().plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df.pct_change().clip(upper=1).plot()
# Out:
# <AxesSubplot:xlabel='Year'>
